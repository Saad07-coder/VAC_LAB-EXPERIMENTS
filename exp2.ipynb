# %% [markdown]
# ## Write a program that accepts a user’s name as input and displays a personalized welcome message.

# %%
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name:  Saad
# Welcome Saad
