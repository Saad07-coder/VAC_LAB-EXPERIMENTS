# %% [markdown]
# ## Identify and correct syntax and indentation errors in a given faulty Python script.

# %%
# Faulty python Script
def greet(name)
print("Hello, " + name)

for i in range(3):
    print(i)
  print("Done")

if True:
print("This works")
# Out:
#   File <string>:7
#     print("Done")
#                  ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Right code
def greet(name):
    print("Hello, " + name)

for i in range(3):
    print(i)
    print("Done")

if True:
    print("This works")
# Out:
# 0
# Done
# 1
# Done
# 2
# Done
# This works
