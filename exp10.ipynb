# %% [markdown]
# ## Create a dictionary storing employee details (ID, Name, Salary).

# %%
# Creating an empty dictionary
employees = {}

# Adding employee details
n = int(input("Enter number of employees: "))

for i in range(n):
    emp_id = input("Enter Employee ID: ")
    name = input("Enter Employee Name: ")
    salary = float(input("Enter Employee Salary: "))

    employees[emp_id] = {
        "Name": name,
        "Salary": salary
    }

# Displaying employee details
print("\nEmployee Records:")
for emp_id, details in employees.items():
    print(f"ID: {emp_id}, Name: {details['Name']}, Salary: {details['Salary']}")
# Out:
# Enter number of employees:  4
# Enter Employee ID:  332
# Enter Employee Name:  Saad
# Enter Employee Salary:  6000
# Enter Employee ID:  333
# Enter Employee Name:  jahid
# Enter Employee Salary:  7000
# Enter Employee ID:  331
# Enter Employee Name:  faizan
# Enter Employee Salary:  6500
# Enter Employee ID:  330
# Enter Employee Name:  shubham
# Enter Employee Salary:  8000
# Employee Records:
# ID: 332, Name: Saad, Salary: 6000.0
# ID: 333, Name: jahid, Salary: 7000.0
# ID: 331, Name: faizan, Salary: 6500.0
# ID: 330, Name: shubham, Salary: 8000.0
