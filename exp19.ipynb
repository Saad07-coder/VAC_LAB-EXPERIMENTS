# %% [markdown]
# ## Write a Python program to display all installed packages.

# %%
import pkg_resources

packages = pkg_resources.working_set

for package in packages:
    print(f"{package.project_name}=={package.version}")
# Out:
# C:\Users\SAAD MIRZA\AppData\Local\Temp\ipykernel_2780\358332027.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# MarkupSafe==3.0.2
# absl-py==2.3.1
# anyio==4.10.0
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# asttokens==3.0.0
# astunparse==1.6.3
# async-lru==2.0.5
# attrs==25.4.0
# babel==2.17.0
# beautifulsoup4==4.14.2
# bleach==6.3.0
# bottleneck==1.4.2
# brotlicffi==1.2.0.0
# certifi==2026.1.4
# cffi==2.0.0
# charset-normalizer==3.4.4
# colorama==0.4.6
# comm==0.2.3
# contourpy==1.3.3
# cryptography==46.0.5
# cycler==0.12.1
# debugpy==1.8.16
# decorator==5.2.1
# defusedxml==0.7.1
# executing==2.2.1
# fastjsonschema==2.21.2
# flatbuffers==24.3.25
# fonttools==4.61.0
# gast==0.7.0
# google-pasta==0.2.0
# grpcio==1.74.1
# h11==0.16.0
# h5py==3.15.1
# ...
