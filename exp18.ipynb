# %% [markdown]
# ## Create a simple log file writer using file handling.

# %%
from datetime import datetime

# Function to write log
def write_log(message):
    with open("log.txt", "a") as file:
        time_stamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"[{time_stamp}] {message}\n")

# Example usage
while True:
    msg = input("Enter log message (type 'exit' to stop): ")
    
    if msg.lower() == "exit":
        print("Logging stopped.")
        break
    
    write_log(msg)
    print("Message logged successfully!")
# Out:
# Enter log message (type 'exit' to stop):  Hello ! What's upp??
# Message logged successfully!
# Enter log message (type 'exit' to stop):  How are you
# Message logged successfully!
# Enter log message (type 'exit' to stop):  exit
# Logging stopped.
