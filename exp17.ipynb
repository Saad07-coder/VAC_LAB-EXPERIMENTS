# %% [markdown]
# ##  Write a program to read a text file and count number of lines and words.

# %%
# Open the file in read mode
with open("source.txt", "r") as file:
    lines = file.readlines()

# Count lines
line_count = len(lines)

# Count words
word_count = 0
for line in lines:
    words = line.split()
    word_count += len(words)

# Display results
print("Number of lines:", line_count)
print("Number of words:", word_count)
# Out:
# Number of lines: 1
# Number of words: 5
